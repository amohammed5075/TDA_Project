# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/UALR/GA/GA/Repository/paraview/All/t-sne/accurate/t-sne-output-accurate.csv",index_col='Row ID')

# %%
data
# Out:
#        Row ID  Battery Life  Beach Name   UMAP-0   UMAP-1  \
# 0           0     -2.280160           2 -53.0555 -13.6314
# 1           1     -2.280160           4 -53.0555 -13.6315
# 2           2     -2.280160           3 -53.0555 -13.6314
# 3           3     -2.280160           1 -53.0555 -13.6314
# 4           4     -0.084728           0 -53.0556 -13.6314
# ...       ...           ...         ...      ...      ...
# 40051   40051     -0.084728           3  76.1309 -45.7338
# 40052   40052     -0.084728           3  76.1505 -45.7159
# 40053   40053     -0.084728           3  76.1829 -45.6864
# 40054   40054     -0.084728           3  76.2139 -45.6581
# 40055   40055     -0.084728           3  76.2327 -45.6409
#
#        Measurement Timestamp  Turbidity  Water Temperature  Wave Height  \
# 0                 1377849600  -0.111816           0.231392    -1.091450
# 1                 1377990000  -0.036078           0.585168     0.655646
# 2                 1378177200   0.011381           0.703093     0.771348
# 3                 1378224000  -0.032177           1.086350    -0.003855
# 4                 1379498400   0.095571          -0.181347    -0.397242
# ...                      ...        ...                ...          ...
# 40051             1630026000  -0.121568           1.292720     0.169698
# 40052             1630033200  -0.124169           1.292720    -0.177408
# 40053             1630047600  -0.101089           1.263240    -0.293110
# 40054             1630065600  -0.107591           1.499090     0.366391
# 40055             1630080000  -0.124169           1.587530     0.354821
#
#        Wave Period
# 0        -0.568405
# 1         0.076463
# 2         2.011070
# 3         1.366200
# 4         0.076463
# ...            ...
# 40051    -0.568405
# 40052     0.076463
# 40053     0.076463
# 40054     0.721331
# 40055     0.721331
#
# [40056 rows x 10 columns]

# %% [markdown]
# ### Change the below variables values by referring to the TableToPoints filter.
# ![image.png](data:image/png;base64,...)

# %%
# Values for the UMAP algorith
# c = 0
# d = 299
# a = -14.0995
# b = 24.0164

# Values for the t-sne algorithm
c = 0
d = 299
a = -85.1549
b = 86.0861

# %%
u_0_trx = c+(((d-c)/(b-a))*(data['UMAP-0']-a))

# %%
data['u_0_trx'] = u_0_trx

# %%
# Values for the UMAP algorith
# c = 0
# d = 299
# a = -14.8735
# b = 23.5025

# Values for the t-sne algorithm
c = 0
d = 299
a = -86.3297
b = 85.5939

# %%
u_1_trx = c+(((d-c)/(b-a))*(data['UMAP-1']-a))
u_1_trx
# Out:
# 0        126.432856
# 1        126.432682
# 2        126.432856
# 3        126.432856
# 4        126.432856
#             ...
# 40051     70.602140
# 40052     70.633271
# 40053     70.684576
# 40054     70.733793
# 40055     70.763707
# Name: UMAP-1, Length: 40056, dtype: float64

# %%
data['u_1_trx'] = u_1_trx
data
# Out:
#        Row ID  Battery Life  Beach Name   UMAP-0   UMAP-1  \
# 0           0     -2.280160           2 -53.0555 -13.6314
# 1           1     -2.280160           4 -53.0555 -13.6315
# 2           2     -2.280160           3 -53.0555 -13.6314
# 3           3     -2.280160           1 -53.0555 -13.6314
# 4           4     -0.084728           0 -53.0556 -13.6314
# ...       ...           ...         ...      ...      ...
# 40051   40051     -0.084728           3  76.1309 -45.7338
# 40052   40052     -0.084728           3  76.1505 -45.7159
# 40053   40053     -0.084728           3  76.1829 -45.6864
# 40054   40054     -0.084728           3  76.2139 -45.6581
# 40055   40055     -0.084728           3  76.2327 -45.6409
#
#        Measurement Timestamp  Turbidity  Water Temperature  Wave Height  \
# 0                 1377849600  -0.111816           0.231392    -1.091450
# 1                 1377990000  -0.036078           0.585168     0.655646
# 2                 1378177200   0.011381           0.703093     0.771348
# 3                 1378224000  -0.032177           1.086350    -0.003855
# 4                 1379498400   0.095571          -0.181347    -0.397242
# ...                      ...        ...                ...          ...
# 40051             1630026000  -0.121568           1.292720     0.169698
# 40052             1630033200  -0.124169           1.292720    -0.177408
# 40053             1630047600  -0.101089           1.263240    -0.293110
# 40054             1630065600  -0.107591           1.499090     0.366391
# 40055             1630080000  -0.124169           1.587530     0.354821
#
#        Wave Period     u_0_trx     u_1_trx
# 0        -0.568405   56.048029  126.432856
# 1         0.076463   56.048029  126.432682
# 2         2.011070   56.048029  126.432856
# 3         1.366200   56.048029  126.432856
# 4         0.076463   56.047855  126.432856
# ...            ...         ...         ...
# 40051    -0.568405  281.617453   70.602140
# 40052     0.076463  281.651676   70.633271
# 40053     0.076463  281.708249   70.684576
# 40054     0.721331  281.762377   70.733793
# 40055     0.721331  281.795203   70.763707
#
# [40056 rows x 12 columns]

# %%
morse_smalle_df = pd.read_csv('/content/drive/MyDrive/UALR/GA/GA/Repository/paraview/All/t-sne/accurate/morse-smale-segments-tsne-accurate.csv')

# %%
data['u_0_trx'] = data['u_0_trx'].apply(np.floor)

data['u_1_trx'] = data['u_1_trx'].apply(np.floor)

result = pd.DataFrame(columns=['Point ID',	'Structured Coordinates:0',	'Structured Coordinates:1','Structured Coordinates:2',	'AscendingManifold',	'DescendingManifold',	'MorseSmaleManifold',	'SplatterValues',	'SplatterValues_Order'])
for row in data.itertuples():
   column1_value = row.u_0_trx
   column2_value = row.u_1_trx
   result = result.append(morse_smalle_df[(morse_smalle_df['Structured Coordinates:0'] == column1_value) & (morse_smalle_df['Structured Coordinates:1'] == column2_value) & (morse_smalle_df['Structured Coordinates:2'] == 1)],ignore_index=True)
# result.to_csv('filename.CSV', index=False)
  #  result.append(morse_smalle_df[(morse_smalle_df['Structured Coordinates:0'] == column1_value) & (morse_smalle_df['Structured Coordinates:1'] == column2_value)],ignore_index=True)
print(result)
# Out:
# <ipython-input-27-f177445ef722>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(morse_smalle_df[(morse_smalle_df['Structured Coordinates:0'] == column1_value) & (morse_smalle_df['Structured Coordinates:1'] == column2_value) & (morse_smalle_df['Structured Coordinates:2'] == 1)],ignore_index=True)
#       Point ID Structured Coordinates:0 Structured Coordinates:1  \
# 0       127856                       56                      126
# 1       127856                       56                      126
# 2       127856                       56                      126
# 3       127856                       56                      126
# 4       127856                       56                      126
# ...        ...                      ...                      ...
# 39718   111281                      281                       70
# 39719   111281                      281                       70
# 39720   111281                      281                       70
# 39721   111281                      281                       70
# 39722   111281                      281                       70
#
#       Structured Coordinates:2 AscendingManifold DescendingManifold  \
# 0                            1                49                  0
# 1                            1                49                  0
# 2                            1                49                  0
# 3                            1                49                  0
# 4                            1                49                  0
# ...                        ...               ...                ...
# 39718                        1                15                  0
# 39719                        1                15                  0
# 39720                        1                15                  0
# 39721                        1                15                  0
# 39722                        1                15                  0
#
#       MorseSmaleManifold  SplatterValues SplatterValues_Order
# 0                     50         69.0856               230623
# 1                     50         69.0856               230623
# 2                     50         69.0856               230623
# 3                     50         69.0856               230623
# 4                     50         69.0856               230623
# ...                  ...             ...                  ...
# 39718                 16          0.0000                99856
# 39719                 16          0.0000                99856
# 39720                 16          0.0000                99856
# 39721                 16          0.0000                99856
# 39722                 16          0.0000                99856
#
# [39723 rows x 9 columns]

# %%
data['AscendingManifold'] = result['AscendingManifold']
data['MorseSmaleManifold'] = result['MorseSmaleManifold']

# %%
data.to_csv('/content/drive/MyDrive/UALR/GA/GA/Repository/paraview/All/t-sne/accurate/morse-smalle-tsne-accurate.csv')
